# %%
import numpy as np

# %%
import collections

# %%
from collections import Counter

# %%
import pandas as pd

# %%
file1 = open('doc1.txt', 'r')

# %%
file1.read().split()
# Out:
# ['Let',
#  'me',
#  'begin',
#  'by',
#  'saying',
#  'thanks',
#  'to',
#  'all',
#  'you',
#  "who've",
#  'traveled,',
#  'from',
#  'far',
#  'and',
#  'wide,',
#  'to',
#  'brave',
#  'the',
#  'cold',
#  'today.',
#  'We',
#  'all',
#  'made',
#  'this',
#  'journey',
#  'for',
#  'a',
#  'reason.',
#  "It's",
#  'humbling,',
#  'but',
#  'in',
#  'my',
#  'heart',
#  'I',
#  'know',
#  'you',
#  "didn't",
#  'come',
#  'here',
#  'just',
#  'for',
#  'me,',
#  'you',
#  'came',
#  'here',
#  'because',
#  'you',
#  'believe',
#  'in',
#  'what',
#  'this',
#  'country',
#  'can',
#  'be.',
#  'In',
#  'the',
#  'face',
#  'of',
#  'war,',
#  'you',
#  'believe',
#  'there',
#  'can',
#  'be',
#  'peace.',
#  'In',
#  'the',
#  'face',
#  'of',
#  'despair,',
#  'you',
#  'believe',
#  'there',
#  'can',
#  'be',
#  'hope.',
#  'In',
#  'the',
#  'face',
#  'of',
#  'a',
#  'politics',
#  "that's",
#  'shut',
#  'you',
#  'out,',
#  "that's",
#  'told',
#  'you',
#  'to',
# ...

# %%
words_1= file1.read().split()

# %%
Counter_1 = counter(words_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-410260c214f6> in <module>
# ----> 1 Counter_1 = counter(words_1)
#
# TypeError: 'Counter' object is not callable

# %%
top_five = counter.most_common(5)

# %%
print(top_five)
# Out:
# []
